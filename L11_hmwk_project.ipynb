# %% [markdown]
# <a href="https://colab.research.google.com/github/roasfora/just_test/blob/main/L11_hmwk_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('spotify_data clean.csv')
df.head()
# Out:
#                  track_id                                       track_name  \
# 0  3EJS5LyekDim1Tf5rBFmZl                    Trippy Mane (ft. Project Pat)
# 1  1oQW6G2ZiwMuHqlPpP27DB                                             OMG!
# 2  7mdkjzoIYlf1rx9EtBpGmU                                      Hard 2 Find
# 3  67rW0Zl7oB3qEpD5YWWE5w  Still Get Like That (ft. Project Pat & Starrah)
# 4  15xptTfRBrjsppW0INUZjf                            ride me like a harley
#
#    track_number  track_popularity  explicit artist_name  artist_popularity  \
# 0             4                 0      True       Diplo                 77
# 1             1                 0      True    Yelawolf                 64
# 2             1                 4      True   Riff Raff                 48
# 3             8                30      True       Diplo                 77
# 4             2                 0      True     Rumelis                 48
#
#    artist_followers                      artist_genres  \
# ...

# %%
df.shape
# Out:
# (8582, 15)

# %%
df.dtypes
# Out:
# track_id               object
# track_name             object
# track_number            int64
# track_popularity        int64
# explicit                 bool
# artist_name            object
# artist_popularity       int64
# artist_followers        int64
# artist_genres          object
# album_id               object
# album_name             object
# album_release_date     object
# album_total_tracks      int64
# album_type             object
# track_duration_min    float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# track_id                 0
# track_name               0
# track_number             0
# track_popularity         0
# explicit                 0
# artist_name              3
# artist_popularity        0
# artist_followers         0
# artist_genres         3361
# album_id                 0
# album_name               0
# album_release_date       0
# album_total_tracks       0
# album_type               0
# track_duration_min       0
# dtype: int64

# %%
df_clean = df.dropna()

# %%
df_clean.describe()
# Out:
#        track_number  track_popularity  artist_popularity  artist_followers  \
# count   5221.000000       5221.000000        5221.000000      5.221000e+03
# mean       6.465237         53.555258          74.588776      3.383704e+07
# std        6.324842         22.987208          17.178821      4.472907e+07
# min        1.000000          0.000000           2.000000      4.000000e+00
# 25%        1.000000         41.000000          63.000000      1.303279e+06
# 50%        5.000000         59.000000          79.000000      1.096042e+07
# 75%       10.000000         71.000000          88.000000      4.771699e+07
# max      102.000000         99.000000         100.000000      1.455421e+08
#
#        album_total_tracks  track_duration_min
# count         5221.000000         5221.000000
# mean            15.893124            3.564999
# std             13.101610            1.133062
# min              1.000000            0.140000
# 25%             10.000000            2.900000
# ...

# %%
df_clean['album_release_date'].dt.day_name()
display(df_clean[['album_release_date', 'release_year', 'release_day_of_week']].head())
# Out:
#   album_release_date  release_year release_day_of_week
# 0         2025-10-31          2025              Friday
# 1         2025-10-31          2025              Friday
# 3         2025-10-31          2025              Friday
# 4         2025-10-30          2025            Thursday
# 5         2025-10-30          2025            Thursday

# %%
df_clean.to_csv('spotify_data_processed.csv', index=False)
print("Processed data saved to 'spotify_data_processed.csv'")
# Out:
# Processed data saved to 'spotify_data_processed.csv'
